# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('cards_db/Ravnica Allegiance/uncommon/1.jpg')
imgplot = plt.imshow(img)
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pytesseract


text = pytesseract.image_to_string(img)
print(text)
# Out:
#
#
#
#
# (Enchantment
#
#
#
# Whenever a creature you control
# attacks alone, it gets +X/+X until
# end of turn, where X is the number
# of creatures you control.
#
# “Tf we cannot have peace, we will have
# justice.”
# —Aurelia
#
# 002/259 U
#
# ™ & © 2019 Wizards of the Coast
# CO aa
